# %% [markdown]
# # Day 01 In-Class Assignment
#
# ---

# %% [markdown]
# ### <p style="text-align: right;"> &#9989;&nbsp; **Put your name here** </p>

# %% [markdown]
# ## Introduction to PLNT_SCI 3550: Data Science for Life Sciences II
#
# <img src="https://i0.wp.com/vadlo.com/Research_Cartoons/Last-line-of-defense---statistics.gif?w=668" style="display:block; margin-left: auto; margin-right: auto; width: 45%" alt="Last line of defense, statistics">
# <p style="font-size:0.85em; text-align: center;">Life in Research. Credits: <a href="https://vadlo.com/" target="_blank">VADLO</a></p>
#
# ### Learning goals for today's in-class assignment
#
# * Make sure you have correctly installed Python and Jupyter notebooks via miniconda
# * Check that you can run your first Python code
# * Extract trend informations from data visualization
#
# ## ⚠️ To keep your files organized, make a new folder for this course. Do not keep all your files jumbled in the Downloads folder.
#
# - Make a dedicated folder, where you'll keep all the Jupyter Notebooks and associated data sets

# %% [markdown]
# ## Agenda for today's class
#
# </p>
#
# 1. [Getting started](#start)
# 2. [Reminder about pre-semester survey (for those that haven't done it)](#survey)
# 3. [Review the class syllabus and in-class procedures](#syllabus)
# 4. [Double-checking that your software is working](#software)
# 5. [Group formation and introduction](#group-formation)
# 6. [Building a concept map for PLNT_SCI 2500](#concept-map)

# %% [markdown]
# ------
# <a id="start"></a>
# # 1. Lets get started!
#
# ## Important Note #1 (read this!)
#
# Unless a situation arises where you are unable to attend class, you are **expected** to be present for every class period. In as much as it is possible, you should notify your instructor if, for any reason, you have to miss class.
#
# ## Important Note #2 (read this, too!)
#
# If you're ever looking for information about class check the course Canvas page (https://umsystem.instructure.com/). If you can't find what you're looking for there, reach out to your instructor via email or Slack.
#
# ## A day in your life as a PLNT_SCI 3550 student
#
# As part of every class session, you should get in the habit doing the following:

# %% [markdown]
# #### &#9989; Download the jupyter notebook of the day
#
# * Go to the <a href="https://umsystem.instructure.com/" target="_blank">class Canvas</a> and download a copy of the notebook for class.
#
# #### &#9989; Follow along with your instructor to check-in on anything you might have missed or been confused about from the pre-class assignment
#
# * During the first ~20 minutes of class, we'll touch base on what you covered in the pre-class assignment
#
# #### &#9989; Listen for details about the plans for that day's class period
#
# * Your instructor will go over what you'll be working on during class
#
# #### &#9989; Work on the in-class activity *with your group*!
#
# * PLNT_SCI 3550 is a collaborative course where you actively work on learning new material with your assigned group

# %% [markdown]
# ------
# <a id="survey"></a>
# # 2. Reminder: Pre-semester Survey
#
# If you didn't already complete the pre-semester sent to you in an email, please take a moment to do it now.
#
# #### &#9989; Do This &ndash; Execute the cell below by pressing `Shift` + `Enter` with the cell highlighted to test your access to Microsoft Forms. If you haven't completed the [pre-semester survey](https://forms.cloud.microsoft/r/dFedWezqcM), do it now.

# %%
# Click on the link above if this cell fails to produce a survey form.

from IPython.display import HTML
HTML(
"""
<iframe src="https://forms.cloud.microsoft/r/dFedWezqcM"
width="800px"
height="600px"
frameborder="0"
marginheight="0"
marginwidth="0">Loading...</iframe>
"""
)
# Out:
# <iframe src="https://forms.cloud.microsoft/r/uF7aC1ZQR7"
# width="800px"
# height="600px"
# frameborder="0"
# marginheight="0"
# marginwidth="0">Loading...</iframe>

# %% [markdown]
# ------
# <a id="syllabus"></a>
# # 3. Review the class syllabus and in-class procedures
#
# #### &#9989; Do This - Go to the [course website](https://umsystem.instructure.com/) and review the course syllabus.
#
# * Read through the syllabus and note any questions you may have. If you can't access the syllabus for any reason, let you instructor know.
#
# * We will go through the syllabus as a class.

# %% [markdown]
# ## Day-to-day class structure
#
# We are going to try and form some class habits to make things go smoothly and help keep us on task.
#
# **Step 1:** Download the pre-class notebook from the class website (unless directed to download it from somewhere else). Watch any associated videos, answer questions, complete the assignment and turn it in Canvas by 11:59 pm the day before class. Ideally, pre-class notebooks will be posted (at least) ~48 hours before they are due.
#
# **Step 2:** During class, download the in-class notebook from the class website (or alternate specified location).
#
# **Step 3:** While you wait for class to start, read through the Notebook to get an idea about what we will be doing in class. Before starting on the activity, the instructor will cover concepts from the pre-class assignment and discuss the plans for the day.
#
# **Step 4:** After a classroom-wide discussion, your instructor will prompt you to start working with your assigned group. You are expected to **work with your group** to complete the in-class activity. At the end of class you should be prepared to save your notebook and upload it to the correct location on Canvas or to be "checked-out" by one of your course instructors to get credit for that day's work. During this group work, the instructor, TA, and LAs will float between breakout rooms to help you progress through the assignment and to answer questions.
#
# **Step 5:** Near the end of class, the course instructors may come by and ask that you display the work you did on your in-class notebook&mdash;**this is one of the ways we will ensure that you get credit for coming to class and engaging with the content!** We do not expect that you will have necessarily completed **all** of the assignment, but will award in-class participation based on a **a committed effort to complete as much of the material as possible.**
#
# **Step 6:** Before you leave class, make sure you put your name on the notebooks and turn it in to the Canvas website.

# %% [markdown]
# ---
# <a id="software"></a>
# # 4. Double-checking that your software is working
#
# Prior to the start of the semester, we sent out an admittedly lengthy software set up guide. Our intention was to be as comprehensive as possible with the guide so that you would have the ability to run **all** of the software you would need for this course locally on your computer.
#
# If you haven't yet looked at the software setup guide, you can check it out [here](https://cmse.msu.edu/cmse202/course_materials/SoftwareSetupGuide.html).
#
# If you tried to get all of the software installed locally on your computer, but ran into issues. Today is a good day to ask your classmates or the instructors for help!

# %% [markdown]
# ------
# <a id="group-formation"></a>
# # 5. Time for group interaction!
#
# Your instructor will explain how group formation will work for the semester. Some sections may be using the [CATME](https://catme.org/) software for group formation this semester. You'll work with your group during every class.
#
# Once your instructor assigns you to your groups, make sure to **take a few minutes to share the following details about you to your group**. As a listener try to make sure your learn a bit more about your group members!
#
# **Share:**
# 1. Your name.
# 2. Your major.
# 3. Your reason for taking this class.
# 4. A boring fact about yourself.
#
# Once everyone has had a chance to share, move onto the group activity below!

# %% [markdown]
# ------
# <a id="concept-map"></a>
# # 6. Building a concept map for PLNT_SCI 2500 *as a group*
#
# As you work in groups this semester, it will be important that you actively engage with your group to maximize your learning gains and ensure that you're understanding the course material. From time to time, we may encourage you to use the whiteboards available in class to think through concepts and plan out the code that you're going to write (of course, you can use the whiteboard even if we don't encourage you to do so!)
#
# For your first group activity of the semester, you're going to work with your group to **create a [concept map](https://en.wikipedia.org/wiki/Concept_map) of PLNT_SCI 2500**. Since PLNT_SCI 2500 is a pre-requisite for this course and because many of you first learned to write code in PLNT_SCI 2500, reminding ourselves what was taught in PLNT_SCI 2500 can be a good place to start PLNT_SCI 3550!
#
# <img src="https://media.springernature.com/full/springer-static/image/art%3A10.1007%2Fs11165-015-9493-7/MediaObjects/11165_2015_9493_Fig1_HTML.gif?as=webp" style="display:block; margin-left: auto; margin-right: auto; width: 80%" alt="Concept map on climate change">
# <p style="font-size:0.85em; text-align: center;">Example of a concept map to represent climate change. Credits: <a href="https://doi.org/10.1007/s11165-015-9493-7" target="_blank">Eggert et al (2016)</a></p>
#
#
# **In building your concept map of PLNT_SCI 2500, as a group you should discuss the following**:
#
# 1. What would you consider to be 3-4 of the main concepts or themes in PLNT_SCI 2550?
# 2. Within this main concepts, what are some examples that represent those concepts/theme or what skills were necessary to master those concepts?
# 3. Where are the connections or threads that run between the concepts, examples, or skills?
#
# As you come up with answers to these questions, start building your concept map as a group. **You can appoint someone in the group to record your group's thoughts and draw out your concept map, or you can work on it collaboratively and take turns adding content to the map**.
#
# **You may find it useful to look at the course website from PLNT_SCI 2500**: https://ejamezquita.github.io/plnt_sci2500/

# %% [markdown]
# &#9989; Individually, try to write down some notes in your notes that come from your group discussion that summarize the main theme/concepts from 2500 and some of the specific topic and skills that you recall from 2500.

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Do This - Erase the contents of this cell and replace it with your answer to the above question!  (double-click on this text to edit this cell, and hit `shift` + `enter` to save the text)

# %% [markdown]
# &#128101; As a class, if time permits, some of the groups will have an opportunity to present their concept map to the whole class. Make sure someone in the group is prepared to chair their screen to display your map and share a bit about your discussion!

# %% [markdown]
# ----
# <a id="end-of-class"></a>
# ## 7. Day 01 Wrap-up
#
# ### A final check-in
#
# How did things go today? If you're running into issues with the software needs for PLNT_SCI 3550, now is a good time to send a note to your instructor explaining the problem(s) you're running into.
#
# Do you have any other questions or concerns about the class? **Include those in an email to your instructor as well!**.

# %% [markdown]
# ---
#
# ## Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Canvas web page.  Go to the "In-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you next class!
#
# Material drawn with permission from:
# <br>
# &#169; Copyright 2025. Department of Computational Mathematics, Science and Engineering&mdash;Michigan State University
#
# Adapted for:
# <br>
# &#169; Copyright 2026,  Division of Plant Science &amp; Technology&mdash;University of Missouri
