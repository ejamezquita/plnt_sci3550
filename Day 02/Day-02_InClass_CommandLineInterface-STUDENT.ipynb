# %% [markdown]
# # Day 02 In-class Assignment
#
# ---

# %% [markdown]
# ### <p style="text-align: right;"> &#9989;&nbsp; **Put your name here** </p>
#
# #### <p style="text-align: right;"> &#9989;&nbsp; Put your group member names here</p>

# %% [markdown]
# ## Practice with the Command Line Interface (CLI)
#
# <img src="https://www.explainxkcd.com/w/images/d/d2/unixkcd.png" style="display:block; margin-left: auto; margin-right: auto; width: 75%" alt="altered xkcd website to mimic a Unix shell">
# <p style="font-size:0.85em; text-align: center;">Credits: <a href="https://www.explainxkcd.com/wiki/index.php/unixkcd" target="_blank">xkcd.com</a></p>

# %% [markdown]
# ## Learning goals for today's class:
#
# By the end of class, you should:
#
# * Be more comfortable using the command line interface to:
#      * create and move between directories on your computer
#      * move, copy, and edit files
#      * download files from the internet
#      * run Python scripts
# * Be able to Enter the "vi" text editor, edit a file, and gracefully exit the text editor (all from starting on the command line)
# * Be able to run command line commands from inside of a Jupyter notebook
#
# ## Agenda for today's class
#
# 1. [Revisiting common commandline commands](#commands)
# 1. [Downloading files from the command line using `curl`](#curl)
# 1. [Setting up a directory using the command line](#directories)
# 1. [Downloading and editing a simple (broken) Python script](#script)
# 1. [Modifying another Python script, but this time with the `vi` text editor](#vi)
# 1. [Testing out command line commands from **inside** a Jupyter notebook](#jupyter-commands)

# %% [markdown]
# ------
# <a id="commands"></a>
# ## 1. Revisting common command line commands
#
# **&#9989; Question 1**
#
# Before you dive into today's activity, take a moment to remind yourself of some of the commands that came up in the pre-class assignment. If you don't remember what they do, check in your with your group or your instructor.
#
# **Note**: there might be a few in this list that _didn't_ come up, so make note of them and figure out what they do!
#
# * `clear`
# * `pwd`
# * `ls`
# * `cd [directory]`
# * `cd ..`
# * `cd .`
# * `cd ~`
# * `cd -`
# * `cd /`
# * `touch [new file]`
# * `cp`
#     * `cp [file] [new file]`
#     * `cp -r [folder] [new folder]`
# * `mv`
#     * `mv [path to file/folder] [new path to file/folder]` (note that this can be used for relocating files or renaming files)
# * `rm`
#     * `rm [file]`
#     * `rm -r [folder]`
# * `less [file]`
# * `more [file]`

# %% [markdown]
# **&#9989; Question 2**
#
# Remind yourself how you can interact with Python on the commandline as well by revisiting these commands:
#
# * `python`
#     * `import random`
#     * `random.randint(1,100)`
#     * `exit()`
# * `ipython`
#     * `import numpy as np`
#     * `np.linspace(0,100,5)`
#     * `ls`
#     * `pwd`
#     * `cd`
#     * `exit()`

# %% [markdown]
# ------
# <a id="curl"></a>
# ## 2. Downloading files from the command line using `curl`
#
# Not only can you create, move, copy, and delete files on the command line, there are also commands that allow you to download files from the internet.
#
# One such command for doing this is the `curl` command. Since you may not be familiar with this command, one option would be to do a quick google search for "curl unix command" which would bring up a page like this one: https://www.tutorialspoint.com/unix_commands/curl.htm
#
# Of course, most command line commands also have a built-in set of documentation that explains what the command does and how it works. For most of the Unix interfaces, you can access this using the `man` command, to access the "manual" for that command.
#
# Try running the following command (it may or may not work for your particular case):
#
# ``` bash
# man curl
# ```
#
# If your terminal complains that `man` is undefined, you can always [duckduckgo "unix man curl"](https://duckduckgo.com/?t=ffab&q=unix+man+curl&ia=web). The "unix" bit is key for a good search.
#
# Either way should bring up the manual for the `curl` command. If on the terminal, you can step through this file one line at a time by pressing <kbd>Return</kbd> or <kbd>Enter</kbd> on your keyboard, or if you want to page through a page at a time you can press <kbd>F</kbd> or <kbd>B</kbd> to move forward and backward respectively. To quit out of the manual page, press <kbd>Q</kbd>.
#
# **&#9989; Question 3**
#
# + What information does the `curl` command need to download a file from the internet?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# **&#9989; Question 4**
#
# - Does `curl` save the data to a file by default or does it just output to the terminal?
# - If it doesn't output it to a file by default, what flag (using `-` or `--`) do you need to use to make it do so?
# - Is there more than one flag that can do this?
#
# To test this out, you can experiment a bit by using the README.md file from supplemental repository for the course:
#
#      https://raw.githubusercontent.com/msu-cmse-courses/cmse202-F22-data/main/README.md
#
# *Put your answer here.*

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# **&#9989; Question 5**
#
# Using what you've learned, what would be the command to download the README.md file from the course website such that it is saved using the same filename?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> `Put your answer here.`

# %% [markdown]
# **&#9989; Task 6**
#
# Confirm that you're right by running your command on your terminal (if you haven't done so already). Once you're sure it works as intended, feel free to delete that file using `rm`.

# %% [markdown]
# ------
# <a id="directories"></a>
#
# ## 3. Setting up a PLNT_SCI 3550 directory using the command line
#
# If you've haven't already, in this section you're going practice setting up a directory structure for storing content related to this course.
#
# **&#9989; Task 7**
#
# Using the **command line interface** do the following:
#
# * Create a new directory in your home directory called `plntsci3550` (if you can't remember which command to use, ask your group for help!)
# * Then, **inside** the `plntsci3550` directory, create two additional directories: `notebooks` and `scripts` (remind yourself how to change directories)
# * Double-check that everything worked by running the `pwd` and `ls` commands to poke around in your new directories.
# * If you already have some class notebooks, try using the `mv` command to move them into your new directories&mdash;this might be a little tricky at first!

# %% [markdown]
# ## &#128721; STOP
#
# Check in with an instructor and show your work!

# %% [markdown]
# ---
# <a id="script"></a>
# ## 4. Downloading and editing a simple (broken) Python script
#
# Now that you have a directory structure set up for the class, let's download a Python script into your new `scripts` directory.
#
# **&#9989; Task 8**
#
# Make sure to navigate into your `scripts` directory on the command line and then use `curl` to download the following script (make sure you use the right flag so that it is saved as `fib.py`:
#
#      https://raw.githubusercontent.com/msu-cmse-courses/cmse202-F22-data/main/code_samples/fib.py

# %% [markdown]
# **&#9989; Task 9**
#
# Now that you have the file downloaded, do the following:
#
# 1. Run the script on the command line using Python and look at the results.
# 2. Open the file and take a look at the comments. Do you understand what the code is doing?
#     * Is there anything in the code that you've never seen before?
#     *  If so, discuss these new components with your group and see if you can make sense of them.
#     *  Specifically, do you understand what the following code is doing?
#
# ``` python
# if __name__== "__main__":
#     main()
# ```
# 3. Is the code correctly doing what it is meant to do? If not, can you figure out what's going wrong?

# %% [markdown]
# **&#9989; Question 10**
#
# Is the cell below, **explain**:
#
# * what the entire code is doing
# * what is supposed to do
# * how you might fix it
# * anything you didn't originally understand about the code (along with an explanation of what you learned about the confusing code)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# **&#9989; Task 11**
#
# Now that you know what's wrong with the code, **fix it!**
#
# * Edit the file with your solution and then re-run the code to make sure it works as intended.

# %% [markdown]
# ------
# <a id="vi"></a>
#
# ## 5. Modifying another Python script, but this time with the `vi` text editor
#
# Time to fix another script, but instead of editing the file withing the Jupyter text editor, you will modify the script using the CLI default editor: [`vi`](https://en.wikipedia.org/wiki/Vi).
#
# The script below is designed to calculate the $x$-position and $y$-position of a projectile as a function of time:
#
# $$x(t) = v_{0}\;t\cos(\theta)$$
# $$y(t) = v_{0}\;t\sin(\theta) - \frac{1}{2}gt^2$$
#
# where $v_0$ is the magnitude of the initial velocity in meters per second, $\theta$ is the angle that that the projectile is launched at in radians, $g$ is the acceleration due to gravity in meters per seconds-squared, and $t$ is the time in seconds.
#
# **You only need to understand what the code is doing so that you can modify it a bit.** Don't worry about the actual physics.

# %% [markdown]
# **&#9989; Task 12**
#
# - Download the following script in your `scripts` directory using the command line:
# ```
#    https://raw.githubusercontent.com/msu-cmse-courses/cmse202-F22-data/main/code_samples/projectile_motion.py
# ```
# - **Test it out** by running it on the command line.
# - You should find that when the script runs, it makes an image called `x_vs_time.png`.
#     - You can find this image by looking for it on your Jupyter "home page". It should look something like this:
#
# <img src="https://i.ibb.co/VvvYGQn/x-vs-time.png" style="display:block; margin-left: auto; margin-right: auto; width: 40%" alt="linear plot of x-distance vs time.">

# %% [markdown]
# **&#9989; Task 13**
#
# - Make a copy of the working script using the command line.
# - Call this new file `projectile_motion_2.py` (clever name, no?)
# - What was the command you used to make the copy of the original?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### Opening the file with vi
#
# **&#9989; Task 14**
#
# Using the `vi` directions from the Pre-Class, let's try opening the copy of the original script and making a few minor changes:
#
# * Open `projectile_motion_2.py` using the `vi` command on the command line
# * Make the following changes to the script:
#      * Change the call to the `compute_trajectory` function in the `main` function so that `velocity = 750` and `angle = 45`. **Do not alter the `compute_trajectory` function itself**.
# * Save and quit the file.
# * Test out your new function by running the script on the command line.
#
# If everything went as planned, you should have a new plot of $x$ as a function of time that looks like this (indicating that the projectile traveled farther):
#
# <img src="https://i.ibb.co/Kb286ZY/x-vs-time.png" style="display:block; margin-left: auto; margin-right: auto; width: 40%" alt="modified linear plot of x-distance vs time.">

# %% [markdown]
# ### Can we do something a little more interesting?
#
# It would be more informative to see how the project traveled vertically since it should make an upside-down parabola: start out going up,  slow down, and fall down. Let's plot **$y$ as a function of time**.
#
# **&#9989; Task 15**
#
# **Using `vi`**, make a new function that plots `y` as a function of time.
# - Use the pre-existing `plot_x_vs_time` as a basis for your new function.
# - This can be a bit tedious if you're just using the insert mode in `vi`, but there are some additional `vi` commands to make our task easier. Try out the following:
#     * Once you open the file in `vi`, move your cursor to the front of the line where `def plot_x_vs_time` is.
#     * Press <kbd>v</kbd> and then move your cursor down until the entire function is highlighted.
#     * Once the entire function is highlighted, press <kbd>y</kbd> for "yank" (copy) and then move your cursor down to a blank line below the `plot_x_vs_time` function
#     * Press <kbd>p</kbd> for "paste".
#     * You should find that a duplicate version of the new function exists.
#     * You can now use insert mode to modify that function!
#
# There's a lot that `vi` can do once you start learning some of the commands and there are a lot of resources available for learning the commands (like this simple [cheat sheet](https://ryanstutorials.net/linuxtutorial/cheatsheetvi.php)).
#
# In your new version of the Python script, make sure you call your new function inside the `main` function and ensure that it saves a new file called `y_vs_time.png`. You should get something that looks like this:
#
# <img src="https://i.ibb.co/7WY2kBz/y-vs-time.png" style="display:block; margin-left: auto; margin-right: auto; width: 40%" alt="modified linear plot of y-distance vs time.">
#
# Much more interesting!

# %% [markdown]
# ------
# <a id="jupyter-commands"></a>
#
# ## 6. Testing out command line commands from **inside** a Jupyter notebook
#
# You can also run terminal commands from **inside** the Jupyter Notebook itself.
#
# ### Using `!`
#
# One way to access command line commands from *inside* your Jupyter notebook is to use the exclamation point/bang symbol, `!`. This symbol actually tells the Jupyter notebook to run the command from the terminal where you initially typed `jupyter notebook`.
#
# **&#9989; Task 16**
#
# - Try running the following cell to see what happens. Do the results make sense?

# %%
# !pwd
# !ls
# Out:
# /home/eah4d/documents/data_for_life_science/02 Day 02
# Day-02_In-Class_CommandLineInterface-STUDENT.ipynb
# Day-02_Pre-Class_ReflectionAndCommandLineInterface-STUDENT.ipynb
# fib.py
# projectile_motion.py
# README.md

# %% [markdown]
# **&#9989; Task 17**
#
# - **Carefully** try executing some of the other command line commands you've learned using `!`.
# - Make sure you know what you expect the command to **before you run it!**
#
# Did all of the commands you tried work? Which, if any, didn't? You may want to experiment with using more than one cell.

# %%
# Test out some "!" commands here

# %% [markdown]
# ### Using the built-in IPython command line commands
#
# Because Jupyter notebooks are also **IPython** notebooks you can run some of the same commands that are available to you when you're using the IPython command prompt.
#
# **&#9989; Task 18**
#
# Run the following two cells. Do the results makes sense?

# %%
pwd
# Out:
# '/home/eah4d/documents/data_for_life_science/02 Day 02'

# %%
ls
# Out:
# Day-02_In-Class_CommandLineInterface-STUDENT.ipynb
# Day-02_Pre-Class_ReflectionAndCommandLineInterface-STUDENT.ipynb
# fib.py
# projectile_motion.py
# README.md

# %% [markdown]
# **&#9989; Question 19**
#
# Combine the two commands above into a single cell.
# - Does it work?
# - If not, why not?
# - What is happening with how the Jupyter notebook is interpreting the information?

# %%
# Test out putting both commands in the same cell here

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# **&#9989; Task 20**
#
# Experiment with other commands to determine which ones work and which ones don't. **Proceed with caution!**

# %%
# Experiment here and create cells as necessary

# %% [markdown]
# ---
#
# ## Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Canvas web page.  Go to the "In-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you next class!
#
# Material drawn with permission from:
# <br>
# &#169; Copyright 2025. Department of Computational Mathematics, Science and Engineering&mdash;Michigan State University
#
# Adapted for:
# <br>
# &#169; Copyright 2026,  Division of Plant Science &amp; Technology&mdash;University of Missouri
